# %%
import pandas as pd

cities = "weather_data.csv"
cities_df = pd.read_csv(cities)
cities_df = cities_df.rename(columns={"Unnamed:0" : "City_ID"})
cities_html = cities_df.to_html('cities_html')
# cities_df = cities_df.index.rename('City_ID')
cities_df
# Out:
#      Unnamed: 0              City  Cloudiness Country        Date  Humidity  \
# 0             0           Sal Rei           3      CV  1569720789        84
# 1             1       East London         100      ZA  1569720790        93
# 2             2         Busselton           0      AU  1569720413        68
# 3             3          Chapleau          75      CA  1569720790        75
# 4             4           Iqaluit          90      CA  1569720790        93
# 5             5           Qaanaaq           0      GL  1569720790        68
# 6             6           Rikitea           6      PF  1569720791        86
# 7             7      Puerto Ayora           0      EC  1569720791        64
# 8             8           Ushuaia          90      AR  1569720791        75
# 9             9              Dali           0      CN  1569720791        48
# 10           10        Chokurdakh         100      RU  1569720791        88
# ...
